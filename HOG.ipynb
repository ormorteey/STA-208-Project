# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
import shutil
import seaborn as sn
from os import listdir, walk, getcwd, mkdir
from os.path import isfile, join, sep
import matplotlib.pyplot as plt

from skimage.feature import hog
from skimage.io import imread, imshow
from skimage.feature import hog
from sklearn.svm import SVC 
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

from sklearn import metrics
from sklearn.preprocessing import LabelEncoder

# import resizing snippets
from conversion import *

# %%
# Create a fresh SVMsubdirectory structure below
# If SVM or any of SVM subdirectory exists, then it removes the SVM subdirectory and create a new SVM folder with the structure below
# 
# +---.ipynb_checkpoints
# +---data
# |   \---Coronahack-Chest-XRay-Dataset
# |       \---Coronahack-Chest-XRay-Dataset
# |           +---SVM
# |           |   +---test_modified
# |           |   +---test_unique
# |           |   +---train_modified
# |           |   \---train_unique
# |           +---test
# |           \---train
# \---__pycache__


dir_path = "data/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset"
subpaths = ["test_modified","train_modified","test_unique","train_unique"]

i = 0
loop_count = 0
while i < 4:
    loop_count += 1
    if loop_count == 7:
        break
    try:
        path = dir_path + '/SVM/' + subpaths[i]
        os.mkdir(path)
    except FileExistsError:
        # if folder exist then try remove the whole SVM subdirectory
        print("Directory " , 'SVM/' + subpaths[i] ,  " already exists")
        try:
            shutil.rmtree(dir_path + '/SVM/')
        except OSError as e:
            print("Error: %s : %s" % (dir_path, e.strerror))
    except OSError:
        print ("Creation of the directory %s failed" % subpaths[i])
        path = dir_path + '/SVM/'
        os.mkdir(path)
    else:
        print ("Successfully created the directory %s " % subpaths[i])
        i += 1
# Out:
# Directory  SVM/test_modified  already exists
# Creation of the directory test_modified failed
# Successfully created the directory test_modified
# Successfully created the directory train_modified
# Successfully created the directory test_unique
# Successfully created the directory train_unique

# %%
filename = "data/Chest_xray_Corona_Metadata.csv"
meta_df = pd.read_csv(filename, header=0)
meta_df.head(10)
# Out:
#    Unnamed: 0   X_ray_image_name   Label Dataset_type Label_2_Virus_category  \
# 0           0  IM-0128-0001.jpeg  Normal        TRAIN                    NaN
# 1           1  IM-0127-0001.jpeg  Normal        TRAIN                    NaN
# 2           2  IM-0125-0001.jpeg  Normal        TRAIN                    NaN
# 3           3  IM-0122-0001.jpeg  Normal        TRAIN                    NaN
# 4           4  IM-0119-0001.jpeg  Normal        TRAIN                    NaN
# 5           5  IM-0117-0001.jpeg  Normal        TRAIN                    NaN
# 6           6  IM-0115-0001.jpeg  Normal        TRAIN                    NaN
# 7           7  IM-0189-0001.jpeg  Normal        TRAIN                    NaN
# 8           8  IM-0187-0001.jpeg  Normal        TRAIN                    NaN
# 9           9  IM-0185-0001.jpeg  Normal        TRAIN                    NaN
#
#   Label_1_Virus_category
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN

# %%
# create dict mapping image names to labels
label_dict = dict()
lim = 10
i = 0
for i, row in meta_df.iterrows():
    label_dict[row.X_ray_image_name] = [row.Label, row.Label_2_Virus_category, row.Label_1_Virus_category]
CLASS_NAMES = meta_df.Label.unique()

# %%
def collect_files(path, subpaths, label = False):
    """Collate paths of files (images)
    
    Args:
        path (type = string): the folder path of the images
        subpath (type = list): subdirectories of paths
        labels (type = boolean): collate corresponding labels for images. Default to False

    Returns:
        tuple (f,l) where:
            f (type = list): List of filepaths
            l (type = list): List of corresponding labels to f
    """
    f=[]
    l=[]
    i=0
    for subpath in subpaths:
        for (dirpath, dirnames, filenames) in walk("{}/{}".format(path,subpath)):
            for file in filenames:
                f.append("{}/{}/{}".format(path,subpath,file))
                if label == True:
                    l.append(label_dict[file][0])
            break
    return f,l

# %%
def shape_rgb_or_grey(img):
    """number of rows, columns and transform image channels to string
    
    Args:
        img (image): image
    Returns:
        list (shp[0], shp[1], color) where:
        shp[0] (type = int): number of rows
        shp[1] (type = int): number of columns 
        color (type = string): img channel type (RGB or GREY)
    """
    
    shp = img.shape
    color = "RGB" if len(shp) == 3 else "GREY"
    return [shp[0], shp[1], color] 

def summarize_images(f,meta_df):
    '''Statistical summary of element of a list of filepath (f)
    
    Args:
        f (type = list): list of image filepaths
    Returns:
        list (df_sizes, bad_images) where:
        df_sizes (type = dataframe): dataframe containing images attributes such as name, dataset_type, extension, color, label, heigth, width, and aspect ratio) 
        bad_images (type = list): images not found in meta_df (Chest_xray_Corona_Metadata)  
    '''
    datasplit_list=[]
    row_nums=[]
    col_nums=[]
    aspect_ratios=[]
    name_short=[]
    labels_list=[]
    file_type=[]
    color_list=[]
    bad_images=[]
    print("--- Parsing {} images ---".format(len(f)))
    print_every = 500
    i = 0

    for filename in f:
        file_short = filename.split("/")[-1]
        file_ext = filename.split(".")[-1]
        if ( file_ext in ["jpeg","jpg","png"]):
            if (i % print_every == 0):
                print("-> {} images parsed".format(i))
            img = imread(filename)
            try:
                data_split = meta_df[meta_df.X_ray_image_name == file_short].Dataset_type.values[0]
                data_label = meta_df[meta_df.X_ray_image_name == file_short].Label.values[0]
                datasplit_list.append(data_split)
                rows, cols, color = shape_rgb_or_grey(img)
                row_nums.append(rows)
                col_nums.append(cols)
                aspect_ratios.append(cols/rows)
                name_short.append(filename.split("/")[-1])
                labels_list.append(data_label)
                file_type.append(file_ext)
                color_list.append(color)
                i += 1
            except ValueError:
                print(ValueError)
                print("{} - shape = {}".format(filename, img.shape))
            except IndexError:
                bad_images.append(file_short)
                print(f'--> {file_short} is not in metadata. Skipping.')
            except:
                print("Unexpected error:", sys.exc_info()[0])
                print(file_short)
                raise

        else:
            print("Skipping {}.".format(filename))

    # summarize image sizes
    data = {"name": name_short, "dataset_type": datasplit_list, "ext": file_type, "color": color_list, "label": labels_list, "n_rows": row_nums, "n_cols": col_nums, "asp_ratio": aspect_ratios}
    df_sizes = pd.DataFrame(data=data,columns=["name", "dataset_type", "ext", "color", "label", "n_rows", "n_cols", "asp_ratio"])
    print(f"--- There were {len(bad_images)} images not included in the metadata .csv ---")
    return [df_sizes, bad_images]


# visualize distribution of image sizes
def df_size_plots(df_sizes):
    
    '''Plots heat map of file height and with and a histogram of image channels
    
    Args:
        df_sizes (type = dataframe): dataframe containing images attributes such as name, dataset_type, extension, color, label, heigth, width, and aspect ratio) 
    '''
    
    fig, axs = plt.subplots(1,2,figsize=(10,3))
    # img size distribution
    hist2d = axs[0].hist2d(df_sizes["n_rows"],df_sizes["n_cols"],bins=50, cmap=plt.cm.jet)
    plt.colorbar(hist2d[3],ax=axs[0])
    axs[0].set_title("Image Size Distribution")
    axs[0].set_xlabel("# Rows")
    axs[0].set_ylabel("# Cols")
    # rgb/color distribution
    colors = ["RGB","GREY"]
    vals = [df_sizes[df_sizes["color"]==color].shape[0] for color in colors]
    axs[1].bar(colors,vals)
    axs[1].set_title("Image Color Distribution")
    axs[1].set_ylabel("Count")
    plt.show()

# %%
path="data/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset"
subpaths=["test","train"]
f,f_label = collect_files(path, subpaths)
df_sizes, bad_images = summarize_images(f, meta_df)
df_sizes.describe()
df_size_plots(df_sizes)
row_mean = df_sizes.n_rows.mean()
col_mean = df_sizes.n_cols.mean()
# Out:
# --- Parsing 5933 images ---
# -> 0 images parsed
# -> 500 images parsed
# --> 1-s2.0-S0929664620300449-gr3_lrg-a.jpg is not in metadata. Skipping.
# --> 1-s2.0-S0929664620300449-gr3_lrg-b.jpg is not in metadata. Skipping.
# --> 1-s2.0-S0929664620300449-gr3_lrg-c.jpg is not in metadata. Skipping.
# --> 1-s2.0-S0929664620300449-gr3_lrg-d.jpg is not in metadata. Skipping.
# --> 191F3B3A-2879-4EF3-BE56-EE0D2B5AAEE3.jpeg is not in metadata. Skipping.
# --> 21DDEBFD-7F16-4E3E-8F90-CB1B8EE82828.jpeg is not in metadata. Skipping.
# --> 396A81A5-982C-44E9-A57E-9B1DC34E2C08.jpeg is not in metadata. Skipping.
# --> 3ED3C0E1-4FE0-4238-8112-DDFF9E20B471.jpeg is not in metadata. Skipping.
# --> 5083A6B7-8983-472E-A427-570A3E03DDEE.jpeg is not in metadata. Skipping.
# --> 66298CBF-6F10-42D5-A688-741F6AC84A76.jpeg is not in metadata. Skipping.
# --> 6A7D4110-2BFC-4D9A-A2D6-E9226D91D25A.jpeg is not in metadata. Skipping.
# --> 925446AE-B3C7-4C93-941B-AC4D2FE1F455.jpeg is not in metadata. Skipping.
# --> DE488FE1-0C44-428B-B67A-09741C1214C0.jpeg is not in metadata. Skipping.
# --> FC230FE2-1DDF-40EB-AA0D-21F950933289.jpeg is not in metadata. Skipping.
# -> 1000 images parsed
# --> jkms-35-e79-g001-l-d.jpg is not in metadata. Skipping.
# --> jkms-35-e79-g001-l-e.jpg is not in metadata. Skipping.
# --> kjr-21-e24-g001-l-b.jpg is not in metadata. Skipping.
# --> kjr-21-e24-g001-l-c.jpg is not in metadata. Skipping.
# --> kjr-21-e24-g002-l-b.jpg is not in metadata. Skipping.
# --> kjr-21-e24-g002-l-c.jpg is not in metadata. Skipping.
# --> kjr-21-e24-g003-l-b.jpg is not in metadata. Skipping.
# --> kjr-21-e24-g004-l-a.jpg is not in metadata. Skipping.
# --> kjr-21-e24-g004-l-b.jpg is not in metadata. Skipping.
# -> 1500 images parsed
# -> 2000 images parsed
# -> 2500 images parsed
# -> 3000 images parsed
# -> 3500 images parsed
# -> 4000 images parsed
# -> 4500 images parsed
# -> 5000 images parsed
# -> 5500 images parsed
# --- There were 23 images not included in the metadata .csv ---

# %%
RESIZE_BOOL = True
df_sizes.n_rows.mean()
ROWS = int(row_mean)
COLS = int(col_mean)
           

path="data/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset"
source_subpaths=["test","train"]
dest_subpaths = ["SVM/test_modified","SVM/train_modified"]

# convert_image(source_path,destination_path,num_rows,num_cols,resize,horizontal_reflection,rotate_image,degree,gauss_noise,mean,std_dev,shear_horizontal,horizontal_factor,shear_vertical,vertical_factor,zero_padding,padding_dim,aspect,dimension,label_dict,print_every=100)
# convert_image(source_path,dest_subpath,COLS,ROWS,RESIZE_BOOL,False,False,10,False,50,1,False,0.2,False,0.2,True,600,True,595,label_dict,print_every=200)
   

for i in range(len(source_subpaths)):
    test_path = path + '/' +  source_subpaths[i]
    test_destination_path =  path + '/' +  dest_subpaths[i]
    convert_image(test_path,test_destination_path,COLS,ROWS,RESIZE_BOOL,False,False,10,False,50,1,False,0.2,False,0.2,True,max(COLS,ROWS)+1,True,595,label_dict,print_every=200)
# Out:
# 200 files processed out of 624 files.
# 400 files processed out of 624 files.
# 600 files processed out of 624 files.
#
# Your images are resized at 1328 by 973 and are in the path data/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/SVM/test_modified
#
# --- There were 0 images without labels ---
# 200 files processed out of 5309 files.
# 400 files processed out of 5309 files.
# 600 files processed out of 5309 files.
# 800 files processed out of 5309 files.
# 1000 files processed out of 5309 files.
# 1200 files processed out of 5309 files.
# 1400 files processed out of 5309 files.
# 1600 files processed out of 5309 files.
# 1800 files processed out of 5309 files.
# 2000 files processed out of 5309 files.
# 2200 files processed out of 5309 files.
# 2400 files processed out of 5309 files.
# 2600 files processed out of 5309 files.
# 2800 files processed out of 5309 files.
# 3000 files processed out of 5309 files.
# 3200 files processed out of 5309 files.
# 3400 files processed out of 5309 files.
# 3600 files processed out of 5309 files.
# 3800 files processed out of 5309 files.
# 4000 files processed out of 5309 files.
# 4200 files processed out of 5309 files.
# 4400 files processed out of 5309 files.
# 4600 files processed out of 5309 files.
# 4800 files processed out of 5309 files.
# 5000 files processed out of 5309 files.
# 5200 files processed out of 5309 files.
#
# Your images are resized at 1328 by 973 and are in the path data/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/SVM/train_modified
#
# --- There were 23 images without labels ---

# %%
path="data/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset"
subpaths=["SVM/test_modified","SVM/train_modified"]
f,f_label = collect_files(path, subpaths)
df_sizes, bad_images = summarize_images(f, meta_df)
df_sizes.describe()
df_size_plots(df_sizes)
# Out:
# --- Parsing 5910 images ---
# -> 0 images parsed
# -> 500 images parsed
# -> 1000 images parsed
# -> 1500 images parsed
# -> 2000 images parsed
# -> 2500 images parsed
# -> 3000 images parsed
# -> 3500 images parsed
# -> 4000 images parsed
# -> 4500 images parsed
# -> 5000 images parsed
# -> 5500 images parsed
# --- There were 0 images not included in the metadata .csv ---

# %%
path="data/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset"
source_subpaths=["SVM/test_modified","SVM/train_modified"]
dest_subpaths = ["SVM/test_unique","SVM/train_unique"]

for i in range(len(subpaths)):
    test_path = path + '/' +  source_subpaths[i]
    test_destination_path =  path + '/' +  dest_subpaths[i]
    list_unique_x_ray(test_path,test_destination_path,False,True,True)
# Out:
# 1 files processed out of 415 files.
# 2 files processed out of 415 files.
# 3 files processed out of 415 files.
# 4 files processed out of 415 files.
# 5 files processed out of 415 files.
# 6 files processed out of 415 files.
# 7 files processed out of 415 files.
# 8 files processed out of 415 files.
# 9 files processed out of 415 files.
# 10 files processed out of 415 files.
# 11 files processed out of 415 files.
# 12 files processed out of 415 files.
# 13 files processed out of 415 files.
# 14 files processed out of 415 files.
# 15 files processed out of 415 files.
# 16 files processed out of 415 files.
# 17 files processed out of 415 files.
# 18 files processed out of 415 files.
# 19 files processed out of 415 files.
# 20 files processed out of 415 files.
# 21 files processed out of 415 files.
# 22 files processed out of 415 files.
# 23 files processed out of 415 files.
# 24 files processed out of 415 files.
# 25 files processed out of 415 files.
# 26 files processed out of 415 files.
# 27 files processed out of 415 files.
# 28 files processed out of 415 files.
# 29 files processed out of 415 files.
# 30 files processed out of 415 files.
# 31 files processed out of 415 files.
# 32 files processed out of 415 files.
# 33 files processed out of 415 files.
# 34 files processed out of 415 files.
# 35 files processed out of 415 files.
# 36 files processed out of 415 files.
# 37 files processed out of 415 files.
# 38 files processed out of 415 files.
# 39 files processed out of 415 files.
# 40 files processed out of 415 files.
# 41 files processed out of 415 files.
# 42 files processed out of 415 files.
# 43 files processed out of 415 files.
# 44 files processed out of 415 files.
# 45 files processed out of 415 files.
# 46 files processed out of 415 files.
# 47 files processed out of 415 files.
# 48 files processed out of 415 files.
# 49 files processed out of 415 files.
# 50 files processed out of 415 files.
# 51 files processed out of 415 files.
# 52 files processed out of 415 files.
# 53 files processed out of 415 files.
# 54 files processed out of 415 files.
# 55 files processed out of 415 files.
# 56 files processed out of 415 files.
# 57 files processed out of 415 files.
# 58 files processed out of 415 files.
# 59 files processed out of 415 files.
# 60 files processed out of 415 files.
# 61 files processed out of 415 files.
# 62 files processed out of 415 files.
# 63 files processed out of 415 files.
# 64 files processed out of 415 files.
# 65 files processed out of 415 files.
# 66 files processed out of 415 files.
# 67 files processed out of 415 files.
# 68 files processed out of 415 files.
# 69 files processed out of 415 files.
# 70 files processed out of 415 files.
# 71 files processed out of 415 files.
# 72 files processed out of 415 files.
# 73 files processed out of 415 files.
# 74 files processed out of 415 files.
# 75 files processed out of 415 files.
# 76 files processed out of 415 files.
# 77 files processed out of 415 files.
# 78 files processed out of 415 files.
# 79 files processed out of 415 files.
# 80 files processed out of 415 files.
# 81 files processed out of 415 files.
# 82 files processed out of 415 files.
# 83 files processed out of 415 files.
# 84 files processed out of 415 files.
# 85 files processed out of 415 files.
# 86 files processed out of 415 files.
# 87 files processed out of 415 files.
# 88 files processed out of 415 files.
# 89 files processed out of 415 files.
# 90 files processed out of 415 files.
# 91 files processed out of 415 files.
# 92 files processed out of 415 files.
# 93 files processed out of 415 files.
# 94 files processed out of 415 files.
# 95 files processed out of 415 files.
# 96 files processed out of 415 files.
# 97 files processed out of 415 files.
# 98 files processed out of 415 files.
# 99 files processed out of 415 files.
# 100 files processed out of 415 files.
# 101 files processed out of 415 files.
# 102 files processed out of 415 files.
# 103 files processed out of 415 files.
# 104 files processed out of 415 files.
# 105 files processed out of 415 files.
# 106 files processed out of 415 files.
# 107 files processed out of 415 files.
# 108 files processed out of 415 files.
# 109 files processed out of 415 files.
# 110 files processed out of 415 files.
# 111 files processed out of 415 files.
# 112 files processed out of 415 files.
# 113 files processed out of 415 files.
# 114 files processed out of 415 files.
# 115 files processed out of 415 files.
# 116 files processed out of 415 files.
# 117 files processed out of 415 files.
# 118 files processed out of 415 files.
# 119 files processed out of 415 files.
# 120 files processed out of 415 files.
# 121 files processed out of 415 files.
# 122 files processed out of 415 files.
# 123 files processed out of 415 files.
# 124 files processed out of 415 files.
# 125 files processed out of 415 files.
# 126 files processed out of 415 files.
# 127 files processed out of 415 files.
# 128 files processed out of 415 files.
# 129 files processed out of 415 files.
# 130 files processed out of 415 files.
# 131 files processed out of 415 files.
# 132 files processed out of 415 files.
# 133 files processed out of 415 files.
# 134 files processed out of 415 files.
# 135 files processed out of 415 files.
# 136 files processed out of 415 files.
# 137 files processed out of 415 files.
# 138 files processed out of 415 files.
# 139 files processed out of 415 files.
# 140 files processed out of 415 files.
# 141 files processed out of 415 files.
# 142 files processed out of 415 files.
# 143 files processed out of 415 files.
# 144 files processed out of 415 files.
# 145 files processed out of 415 files.
# 146 files processed out of 415 files.
# 147 files processed out of 415 files.
# 148 files processed out of 415 files.
# 149 files processed out of 415 files.
# 150 files processed out of 415 files.
# 151 files processed out of 415 files.
# 152 files processed out of 415 files.
# 153 files processed out of 415 files.
# 154 files processed out of 415 files.
# 155 files processed out of 415 files.
# 156 files processed out of 415 files.
# 157 files processed out of 415 files.
# 158 files processed out of 415 files.
# 159 files processed out of 415 files.
# 160 files processed out of 415 files.
# 161 files processed out of 415 files.
# 162 files processed out of 415 files.
# 163 files processed out of 415 files.
# 164 files processed out of 415 files.
# 165 files processed out of 415 files.
# 166 files processed out of 415 files.
# 167 files processed out of 415 files.
# 168 files processed out of 415 files.
# 169 files processed out of 415 files.
# 170 files processed out of 415 files.
# 171 files processed out of 415 files.
# 172 files processed out of 415 files.
# 173 files processed out of 415 files.
# 174 files processed out of 415 files.
# 175 files processed out of 415 files.
# 176 files processed out of 415 files.
# 177 files processed out of 415 files.
# 178 files processed out of 415 files.
# 179 files processed out of 415 files.
# 180 files processed out of 415 files.
# 181 files processed out of 415 files.
# 182 files processed out of 415 files.
# 183 files processed out of 415 files.
# 184 files processed out of 415 files.
# 185 files processed out of 415 files.
# 186 files processed out of 415 files.
# 187 files processed out of 415 files.
# 188 files processed out of 415 files.
# 189 files processed out of 415 files.
# 190 files processed out of 415 files.
# 191 files processed out of 415 files.
# 192 files processed out of 415 files.
# 193 files processed out of 415 files.
# 194 files processed out of 415 files.
# 195 files processed out of 415 files.
# 196 files processed out of 415 files.
# 197 files processed out of 415 files.
# 198 files processed out of 415 files.
# 199 files processed out of 415 files.
# 200 files processed out of 415 files.
# 201 files processed out of 415 files.
# 202 files processed out of 415 files.
# 203 files processed out of 415 files.
# 204 files processed out of 415 files.
# 205 files processed out of 415 files.
# 206 files processed out of 415 files.
# 207 files processed out of 415 files.
# 208 files processed out of 415 files.
# 209 files processed out of 415 files.
# 210 files processed out of 415 files.
# 211 files processed out of 415 files.
# 212 files processed out of 415 files.
# 213 files processed out of 415 files.
# 214 files processed out of 415 files.
# 215 files processed out of 415 files.
# 216 files processed out of 415 files.
# 217 files processed out of 415 files.
# 218 files processed out of 415 files.
# 219 files processed out of 415 files.
# 220 files processed out of 415 files.
# 221 files processed out of 415 files.
# 222 files processed out of 415 files.
# 223 files processed out of 415 files.
# 224 files processed out of 415 files.
# 225 files processed out of 415 files.
# 226 files processed out of 415 files.
# 227 files processed out of 415 files.
# 228 files processed out of 415 files.
# 229 files processed out of 415 files.
# 230 files processed out of 415 files.
# 231 files processed out of 415 files.
# 232 files processed out of 415 files.
# 233 files processed out of 415 files.
# 234 files processed out of 415 files.
# 235 files processed out of 415 files.
# 236 files processed out of 415 files.
# 237 files processed out of 415 files.
# 238 files processed out of 415 files.
# 239 files processed out of 415 files.
# 240 files processed out of 415 files.
# 241 files processed out of 415 files.
# 242 files processed out of 415 files.
# 243 files processed out of 415 files.
# 244 files processed out of 415 files.
# 245 files processed out of 415 files.
# 246 files processed out of 415 files.
# 247 files processed out of 415 files.
# 248 files processed out of 415 files.
# 249 files processed out of 415 files.
# 250 files processed out of 415 files.
# 251 files processed out of 415 files.
# 252 files processed out of 415 files.
# 253 files processed out of 415 files.
# 254 files processed out of 415 files.
# 255 files processed out of 415 files.
# 256 files processed out of 415 files.
# 257 files processed out of 415 files.
# 258 files processed out of 415 files.
# 259 files processed out of 415 files.
# 260 files processed out of 415 files.
# 261 files processed out of 415 files.
# 262 files processed out of 415 files.
# 263 files processed out of 415 files.
# 264 files processed out of 415 files.
# 265 files processed out of 415 files.
# 266 files processed out of 415 files.
# 267 files processed out of 415 files.
# 268 files processed out of 415 files.
# 269 files processed out of 415 files.
# 270 files processed out of 415 files.
# 271 files processed out of 415 files.
# 272 files processed out of 415 files.
# 273 files processed out of 415 files.
# 274 files processed out of 415 files.
# 275 files processed out of 415 files.
# 276 files processed out of 415 files.
# 277 files processed out of 415 files.
# 278 files processed out of 415 files.
# 279 files processed out of 415 files.
# 280 files processed out of 415 files.
# 281 files processed out of 415 files.
# 282 files processed out of 415 files.
# 283 files processed out of 415 files.
# 284 files processed out of 415 files.
# 285 files processed out of 415 files.
# 286 files processed out of 415 files.
# 287 files processed out of 415 files.
# 288 files processed out of 415 files.
# 289 files processed out of 415 files.
# 290 files processed out of 415 files.
# 291 files processed out of 415 files.
# 292 files processed out of 415 files.
# 293 files processed out of 415 files.
# 294 files processed out of 415 files.
# 295 files processed out of 415 files.
# 296 files processed out of 415 files.
# 297 files processed out of 415 files.
# 298 files processed out of 415 files.
# 299 files processed out of 415 files.
# 300 files processed out of 415 files.
# 301 files processed out of 415 files.
# 302 files processed out of 415 files.
# 303 files processed out of 415 files.
# 304 files processed out of 415 files.
# 305 files processed out of 415 files.
# 306 files processed out of 415 files.
# 307 files processed out of 415 files.
# 308 files processed out of 415 files.
# 309 files processed out of 415 files.
# 310 files processed out of 415 files.
# 311 files processed out of 415 files.
# 312 files processed out of 415 files.
# 313 files processed out of 415 files.
# 314 files processed out of 415 files.
# 315 files processed out of 415 files.
# 316 files processed out of 415 files.
# 317 files processed out of 415 files.
# 318 files processed out of 415 files.
# 319 files processed out of 415 files.
# 320 files processed out of 415 files.
# 321 files processed out of 415 files.
# 322 files processed out of 415 files.
# 323 files processed out of 415 files.
# 324 files processed out of 415 files.
# 325 files processed out of 415 files.
# 326 files processed out of 415 files.
# 327 files processed out of 415 files.
# 328 files processed out of 415 files.
# 329 files processed out of 415 files.
# 330 files processed out of 415 files.
# 331 files processed out of 415 files.
# 332 files processed out of 415 files.
# 333 files processed out of 415 files.
# 334 files processed out of 415 files.
# 335 files processed out of 415 files.
# 336 files processed out of 415 files.
# 337 files processed out of 415 files.
# 338 files processed out of 415 files.
# 339 files processed out of 415 files.
# 340 files processed out of 415 files.
# 341 files processed out of 415 files.
# 342 files processed out of 415 files.
# 343 files processed out of 415 files.
# 344 files processed out of 415 files.
# 345 files processed out of 415 files.
# 346 files processed out of 415 files.
# 347 files processed out of 415 files.
# 348 files processed out of 415 files.
# 349 files processed out of 415 files.
# 350 files processed out of 415 files.
# 351 files processed out of 415 files.
# 352 files processed out of 415 files.
# 353 files processed out of 415 files.
# 354 files processed out of 415 files.
# 355 files processed out of 415 files.
# 356 files processed out of 415 files.
# 357 files processed out of 415 files.
# 358 files processed out of 415 files.
# 359 files processed out of 415 files.
# 360 files processed out of 415 files.
# 361 files processed out of 415 files.
# 362 files processed out of 415 files.
# 363 files processed out of 415 files.
# 364 files processed out of 415 files.
# 365 files processed out of 415 files.
# 366 files processed out of 415 files.
# 367 files processed out of 415 files.
# 368 files processed out of 415 files.
# 369 files processed out of 415 files.
# 370 files processed out of 415 files.
# 371 files processed out of 415 files.
# 372 files processed out of 415 files.
# 373 files processed out of 415 files.
# 374 files processed out of 415 files.
# 375 files processed out of 415 files.
# 376 files processed out of 415 files.
# 377 files processed out of 415 files.
# 378 files processed out of 415 files.
# 379 files processed out of 415 files.
# 380 files processed out of 415 files.
# 381 files processed out of 415 files.
# 382 files processed out of 415 files.
# 383 files processed out of 415 files.
# 384 files processed out of 415 files.
# 385 files processed out of 415 files.
# 386 files processed out of 415 files.
# 387 files processed out of 415 files.
# 388 files processed out of 415 files.
# 389 files processed out of 415 files.
# 390 files processed out of 415 files.
# 391 files processed out of 415 files.
# 392 files processed out of 415 files.
# 393 files processed out of 415 files.
# 394 files processed out of 415 files.
# 395 files processed out of 415 files.
# 396 files processed out of 415 files.
# 397 files processed out of 415 files.
# 398 files processed out of 415 files.
# 399 files processed out of 415 files.
# 400 files processed out of 415 files.
# 401 files processed out of 415 files.
# 402 files processed out of 415 files.
# 403 files processed out of 415 files.
# 404 files processed out of 415 files.
# 405 files processed out of 415 files.
# 406 files processed out of 415 files.
# 407 files processed out of 415 files.
# 408 files processed out of 415 files.
# 409 files processed out of 415 files.
# 410 files processed out of 415 files.
# 411 files processed out of 415 files.
# 412 files processed out of 415 files.
# 413 files processed out of 415 files.
# 414 files processed out of 415 files.
# 415 files processed out of 415 files.
# 1 files processed out of 2700 files.
# 2 files processed out of 2700 files.
# 3 files processed out of 2700 files.
# 4 files processed out of 2700 files.
# 5 files processed out of 2700 files.
# 6 files processed out of 2700 files.
# 7 files processed out of 2700 files.
# 8 files processed out of 2700 files.
# 9 files processed out of 2700 files.
# 10 files processed out of 2700 files.
# 11 files processed out of 2700 files.
# 12 files processed out of 2700 files.
# 13 files processed out of 2700 files.
# 14 files processed out of 2700 files.
# 15 files processed out of 2700 files.
# 16 files processed out of 2700 files.
# 17 files processed out of 2700 files.
# 18 files processed out of 2700 files.
# 19 files processed out of 2700 files.
# 20 files processed out of 2700 files.
# 21 files processed out of 2700 files.
# 22 files processed out of 2700 files.
# 23 files processed out of 2700 files.
# 24 files processed out of 2700 files.
# 25 files processed out of 2700 files.
# 26 files processed out of 2700 files.
# 27 files processed out of 2700 files.
# 28 files processed out of 2700 files.
# 29 files processed out of 2700 files.
# 30 files processed out of 2700 files.
# 31 files processed out of 2700 files.
# 32 files processed out of 2700 files.
# 33 files processed out of 2700 files.
# 34 files processed out of 2700 files.
# 35 files processed out of 2700 files.
# 36 files processed out of 2700 files.
# 37 files processed out of 2700 files.
# 38 files processed out of 2700 files.
# 39 files processed out of 2700 files.
# 40 files processed out of 2700 files.
# 41 files processed out of 2700 files.
# 42 files processed out of 2700 files.
# 43 files processed out of 2700 files.
# 44 files processed out of 2700 files.
# 45 files processed out of 2700 files.
# 46 files processed out of 2700 files.
# 47 files processed out of 2700 files.
# 48 files processed out of 2700 files.
# 49 files processed out of 2700 files.
# 50 files processed out of 2700 files.
# 51 files processed out of 2700 files.
# 52 files processed out of 2700 files.
# 53 files processed out of 2700 files.
# 54 files processed out of 2700 files.
# 55 files processed out of 2700 files.
# 56 files processed out of 2700 files.
# 57 files processed out of 2700 files.
# 58 files processed out of 2700 files.
# 59 files processed out of 2700 files.
# 60 files processed out of 2700 files.
# 61 files processed out of 2700 files.
# 62 files processed out of 2700 files.
# 63 files processed out of 2700 files.
# 64 files processed out of 2700 files.
# 65 files processed out of 2700 files.
# 66 files processed out of 2700 files.
# 67 files processed out of 2700 files.
# 68 files processed out of 2700 files.
# 69 files processed out of 2700 files.
# 70 files processed out of 2700 files.
# 71 files processed out of 2700 files.
# 72 files processed out of 2700 files.
# 73 files processed out of 2700 files.
# 74 files processed out of 2700 files.
# 75 files processed out of 2700 files.
# 76 files processed out of 2700 files.
# 77 files processed out of 2700 files.
# 78 files processed out of 2700 files.
# 79 files processed out of 2700 files.
# 80 files processed out of 2700 files.
# 81 files processed out of 2700 files.
# 82 files processed out of 2700 files.
# 83 files processed out of 2700 files.
# 84 files processed out of 2700 files.
# 85 files processed out of 2700 files.
# 86 files processed out of 2700 files.
# 87 files processed out of 2700 files.
# 88 files processed out of 2700 files.
# 89 files processed out of 2700 files.
# 90 files processed out of 2700 files.
# 91 files processed out of 2700 files.
# 92 files processed out of 2700 files.
# 93 files processed out of 2700 files.
# 94 files processed out of 2700 files.
# 95 files processed out of 2700 files.
# 96 files processed out of 2700 files.
# 97 files processed out of 2700 files.
# 98 files processed out of 2700 files.
# 99 files processed out of 2700 files.
# 100 files processed out of 2700 files.
# 101 files processed out of 2700 files.
# 102 files processed out of 2700 files.
# 103 files processed out of 2700 files.
# 104 files processed out of 2700 files.
# 105 files processed out of 2700 files.
# 106 files processed out of 2700 files.
# 107 files processed out of 2700 files.
# 108 files processed out of 2700 files.
# 109 files processed out of 2700 files.
# 110 files processed out of 2700 files.
# 111 files processed out of 2700 files.
# 112 files processed out of 2700 files.
# 113 files processed out of 2700 files.
# 114 files processed out of 2700 files.
# 115 files processed out of 2700 files.
# 116 files processed out of 2700 files.
# 117 files processed out of 2700 files.
# 118 files processed out of 2700 files.
# 119 files processed out of 2700 files.
# 120 files processed out of 2700 files.
# 121 files processed out of 2700 files.
# 122 files processed out of 2700 files.
# 123 files processed out of 2700 files.
# 124 files processed out of 2700 files.
# 125 files processed out of 2700 files.
# 126 files processed out of 2700 files.
# 127 files processed out of 2700 files.
# 128 files processed out of 2700 files.
# 129 files processed out of 2700 files.
# 130 files processed out of 2700 files.
# 131 files processed out of 2700 files.
# 132 files processed out of 2700 files.
# 133 files processed out of 2700 files.
# 134 files processed out of 2700 files.
# 135 files processed out of 2700 files.
# 136 files processed out of 2700 files.
# 137 files processed out of 2700 files.
# 138 files processed out of 2700 files.
# 139 files processed out of 2700 files.
# 140 files processed out of 2700 files.
# 141 files processed out of 2700 files.
# 142 files processed out of 2700 files.
# 143 files processed out of 2700 files.
# 144 files processed out of 2700 files.
# 145 files processed out of 2700 files.
# 146 files processed out of 2700 files.
# 147 files processed out of 2700 files.
# 148 files processed out of 2700 files.
# 149 files processed out of 2700 files.
# 150 files processed out of 2700 files.
# 151 files processed out of 2700 files.
# 152 files processed out of 2700 files.
# 153 files processed out of 2700 files.
# 154 files processed out of 2700 files.
# 155 files processed out of 2700 files.
# 156 files processed out of 2700 files.
# 157 files processed out of 2700 files.
# 158 files processed out of 2700 files.
# 159 files processed out of 2700 files.
# 160 files processed out of 2700 files.
# 161 files processed out of 2700 files.
# 162 files processed out of 2700 files.
# 163 files processed out of 2700 files.
# 164 files processed out of 2700 files.
# 165 files processed out of 2700 files.
# 166 files processed out of 2700 files.
# 167 files processed out of 2700 files.
# 168 files processed out of 2700 files.
# 169 files processed out of 2700 files.
# 170 files processed out of 2700 files.
# 171 files processed out of 2700 files.
# 172 files processed out of 2700 files.
# 173 files processed out of 2700 files.
# 174 files processed out of 2700 files.
# 175 files processed out of 2700 files.
# 176 files processed out of 2700 files.
# 177 files processed out of 2700 files.
# 178 files processed out of 2700 files.
# 179 files processed out of 2700 files.
# 180 files processed out of 2700 files.
# 181 files processed out of 2700 files.
# 182 files processed out of 2700 files.
# 183 files processed out of 2700 files.
# 184 files processed out of 2700 files.
# 185 files processed out of 2700 files.
# 186 files processed out of 2700 files.
# 187 files processed out of 2700 files.
# 188 files processed out of 2700 files.
# 189 files processed out of 2700 files.
# 190 files processed out of 2700 files.
# 191 files processed out of 2700 files.
# 192 files processed out of 2700 files.
# 193 files processed out of 2700 files.
# 194 files processed out of 2700 files.
# 195 files processed out of 2700 files.
# 196 files processed out of 2700 files.
# 197 files processed out of 2700 files.
# 198 files processed out of 2700 files.
# 199 files processed out of 2700 files.
# 200 files processed out of 2700 files.
# 201 files processed out of 2700 files.
# 202 files processed out of 2700 files.
# 203 files processed out of 2700 files.
# 204 files processed out of 2700 files.
# 205 files processed out of 2700 files.
# 206 files processed out of 2700 files.
# 207 files processed out of 2700 files.
# 208 files processed out of 2700 files.
# 209 files processed out of 2700 files.
# 210 files processed out of 2700 files.
# 211 files processed out of 2700 files.
# 212 files processed out of 2700 files.
# 213 files processed out of 2700 files.
# 214 files processed out of 2700 files.
# 215 files processed out of 2700 files.
# 216 files processed out of 2700 files.
# 217 files processed out of 2700 files.
# 218 files processed out of 2700 files.
# 219 files processed out of 2700 files.
# 220 files processed out of 2700 files.
# 221 files processed out of 2700 files.
# 222 files processed out of 2700 files.
# 223 files processed out of 2700 files.
# 224 files processed out of 2700 files.
# 225 files processed out of 2700 files.
# 226 files processed out of 2700 files.
# 227 files processed out of 2700 files.
# 228 files processed out of 2700 files.
# 229 files processed out of 2700 files.
# 230 files processed out of 2700 files.
# 231 files processed out of 2700 files.
# 232 files processed out of 2700 files.
# 233 files processed out of 2700 files.
# 234 files processed out of 2700 files.
# 235 files processed out of 2700 files.
# 236 files processed out of 2700 files.
# 237 files processed out of 2700 files.
# 238 files processed out of 2700 files.
# 239 files processed out of 2700 files.
# 240 files processed out of 2700 files.
# 241 files processed out of 2700 files.
# 242 files processed out of 2700 files.
# 243 files processed out of 2700 files.
# 244 files processed out of 2700 files.
# 245 files processed out of 2700 files.
# 246 files processed out of 2700 files.
# 247 files processed out of 2700 files.
# 248 files processed out of 2700 files.
# 249 files processed out of 2700 files.
# 250 files processed out of 2700 files.
# 251 files processed out of 2700 files.
# 252 files processed out of 2700 files.
# 253 files processed out of 2700 files.
# 254 files processed out of 2700 files.
# 255 files processed out of 2700 files.
# 256 files processed out of 2700 files.
# 257 files processed out of 2700 files.
# 258 files processed out of 2700 files.
# 259 files processed out of 2700 files.
# 260 files processed out of 2700 files.
# 261 files processed out of 2700 files.
# 262 files processed out of 2700 files.
# 263 files processed out of 2700 files.
# 264 files processed out of 2700 files.
# 265 files processed out of 2700 files.
# 266 files processed out of 2700 files.
# 267 files processed out of 2700 files.
# 268 files processed out of 2700 files.
# 269 files processed out of 2700 files.
# 270 files processed out of 2700 files.
# 271 files processed out of 2700 files.
# 272 files processed out of 2700 files.
# 273 files processed out of 2700 files.
# 274 files processed out of 2700 files.
# 275 files processed out of 2700 files.
# 276 files processed out of 2700 files.
# 277 files processed out of 2700 files.
# 278 files processed out of 2700 files.
# 279 files processed out of 2700 files.
# 280 files processed out of 2700 files.
# 281 files processed out of 2700 files.
# 282 files processed out of 2700 files.
# 283 files processed out of 2700 files.
# 284 files processed out of 2700 files.
# 285 files processed out of 2700 files.
# 286 files processed out of 2700 files.
# 287 files processed out of 2700 files.
# 288 files processed out of 2700 files.
# 289 files processed out of 2700 files.
# 290 files processed out of 2700 files.
# 291 files processed out of 2700 files.
# 292 files processed out of 2700 files.
# 293 files processed out of 2700 files.
# 294 files processed out of 2700 files.
# 295 files processed out of 2700 files.
# 296 files processed out of 2700 files.
# 297 files processed out of 2700 files.
# 298 files processed out of 2700 files.
# 299 files processed out of 2700 files.
# 300 files processed out of 2700 files.
# 301 files processed out of 2700 files.
# 302 files processed out of 2700 files.
# 303 files processed out of 2700 files.
# 304 files processed out of 2700 files.
# 305 files processed out of 2700 files.
# 306 files processed out of 2700 files.
# 307 files processed out of 2700 files.
# 308 files processed out of 2700 files.
# 309 files processed out of 2700 files.
# 310 files processed out of 2700 files.
# 311 files processed out of 2700 files.
# 312 files processed out of 2700 files.
# 313 files processed out of 2700 files.
# 314 files processed out of 2700 files.
# 315 files processed out of 2700 files.
# 316 files processed out of 2700 files.
# 317 files processed out of 2700 files.
# 318 files processed out of 2700 files.
# 319 files processed out of 2700 files.
# 320 files processed out of 2700 files.
# 321 files processed out of 2700 files.
# 322 files processed out of 2700 files.
# 323 files processed out of 2700 files.
# 324 files processed out of 2700 files.
# 325 files processed out of 2700 files.
# 326 files processed out of 2700 files.
# 327 files processed out of 2700 files.
# 328 files processed out of 2700 files.
# 329 files processed out of 2700 files.
# 330 files processed out of 2700 files.
# 331 files processed out of 2700 files.
# 332 files processed out of 2700 files.
# 333 files processed out of 2700 files.
# 334 files processed out of 2700 files.
# 335 files processed out of 2700 files.
# 336 files processed out of 2700 files.
# 337 files processed out of 2700 files.
# 338 files processed out of 2700 files.
# 339 files processed out of 2700 files.
# 340 files processed out of 2700 files.
# 341 files processed out of 2700 files.
# 342 files processed out of 2700 files.
# 343 files processed out of 2700 files.
# 344 files processed out of 2700 files.
# 345 files processed out of 2700 files.
# 346 files processed out of 2700 files.
# 347 files processed out of 2700 files.
# 348 files processed out of 2700 files.
# 349 files processed out of 2700 files.
# 350 files processed out of 2700 files.
# 351 files processed out of 2700 files.
# 352 files processed out of 2700 files.
# 353 files processed out of 2700 files.
# 354 files processed out of 2700 files.
# 355 files processed out of 2700 files.
# 356 files processed out of 2700 files.
# 357 files processed out of 2700 files.
# 358 files processed out of 2700 files.
# 359 files processed out of 2700 files.
# 360 files processed out of 2700 files.
# 361 files processed out of 2700 files.
# 362 files processed out of 2700 files.
# 363 files processed out of 2700 files.
# 364 files processed out of 2700 files.
# 365 files processed out of 2700 files.
# 366 files processed out of 2700 files.
# 367 files processed out of 2700 files.
# 368 files processed out of 2700 files.
# 369 files processed out of 2700 files.
# 370 files processed out of 2700 files.
# 371 files processed out of 2700 files.
# 372 files processed out of 2700 files.
# 373 files processed out of 2700 files.
# 374 files processed out of 2700 files.
# 375 files processed out of 2700 files.
# 376 files processed out of 2700 files.
# 377 files processed out of 2700 files.
# 378 files processed out of 2700 files.
# 379 files processed out of 2700 files.
# 380 files processed out of 2700 files.
# 381 files processed out of 2700 files.
# 382 files processed out of 2700 files.
# 383 files processed out of 2700 files.
# 384 files processed out of 2700 files.
# 385 files processed out of 2700 files.
# 386 files processed out of 2700 files.
# 387 files processed out of 2700 files.
# 388 files processed out of 2700 files.
# 389 files processed out of 2700 files.
# 390 files processed out of 2700 files.
# 391 files processed out of 2700 files.
# 392 files processed out of 2700 files.
# 393 files processed out of 2700 files.
# 394 files processed out of 2700 files.
# 395 files processed out of 2700 files.
# 396 files processed out of 2700 files.
# 397 files processed out of 2700 files.
# 398 files processed out of 2700 files.
# 399 files processed out of 2700 files.
# 400 files processed out of 2700 files.
# 401 files processed out of 2700 files.
# 402 files processed out of 2700 files.
# 403 files processed out of 2700 files.
# 404 files processed out of 2700 files.
# 405 files processed out of 2700 files.
# 406 files processed out of 2700 files.
# 407 files processed out of 2700 files.
# 408 files processed out of 2700 files.
# 409 files processed out of 2700 files.
# 410 files processed out of 2700 files.
# 411 files processed out of 2700 files.
# 412 files processed out of 2700 files.
# 413 files processed out of 2700 files.
# 414 files processed out of 2700 files.
# 415 files processed out of 2700 files.
# 416 files processed out of 2700 files.
# 417 files processed out of 2700 files.
# 418 files processed out of 2700 files.
# 419 files processed out of 2700 files.
# 420 files processed out of 2700 files.
# 421 files processed out of 2700 files.
# 422 files processed out of 2700 files.
# 423 files processed out of 2700 files.
# 424 files processed out of 2700 files.
# 425 files processed out of 2700 files.
# 426 files processed out of 2700 files.
# 427 files processed out of 2700 files.
# 428 files processed out of 2700 files.
# 429 files processed out of 2700 files.
# 430 files processed out of 2700 files.
# 431 files processed out of 2700 files.
# 432 files processed out of 2700 files.
# 433 files processed out of 2700 files.
# 434 files processed out of 2700 files.
# 435 files processed out of 2700 files.
# 436 files processed out of 2700 files.
# 437 files processed out of 2700 files.
# 438 files processed out of 2700 files.
# 439 files processed out of 2700 files.
# 440 files processed out of 2700 files.
# 441 files processed out of 2700 files.
# 442 files processed out of 2700 files.
# 443 files processed out of 2700 files.
# 444 files processed out of 2700 files.
# 445 files processed out of 2700 files.
# 446 files processed out of 2700 files.
# 447 files processed out of 2700 files.
# 448 files processed out of 2700 files.
# 449 files processed out of 2700 files.
# 450 files processed out of 2700 files.
# 451 files processed out of 2700 files.
# 452 files processed out of 2700 files.
# 453 files processed out of 2700 files.
# 454 files processed out of 2700 files.
# 455 files processed out of 2700 files.
# 456 files processed out of 2700 files.
# 457 files processed out of 2700 files.
# 458 files processed out of 2700 files.
# 459 files processed out of 2700 files.
# 460 files processed out of 2700 files.
# 461 files processed out of 2700 files.
# 462 files processed out of 2700 files.
# 463 files processed out of 2700 files.
# 464 files processed out of 2700 files.
# 465 files processed out of 2700 files.
# 466 files processed out of 2700 files.
# 467 files processed out of 2700 files.
# 468 files processed out of 2700 files.
# 469 files processed out of 2700 files.
# 470 files processed out of 2700 files.
# 471 files processed out of 2700 files.
# 472 files processed out of 2700 files.
# 473 files processed out of 2700 files.
# 474 files processed out of 2700 files.
# 475 files processed out of 2700 files.
# 476 files processed out of 2700 files.
# 477 files processed out of 2700 files.
# 478 files processed out of 2700 files.
# 479 files processed out of 2700 files.
# 480 files processed out of 2700 files.
# 481 files processed out of 2700 files.
# 482 files processed out of 2700 files.
# 483 files processed out of 2700 files.
# 484 files processed out of 2700 files.
# 485 files processed out of 2700 files.
# 486 files processed out of 2700 files.
# 487 files processed out of 2700 files.
# 488 files processed out of 2700 files.
# 489 files processed out of 2700 files.
# 490 files processed out of 2700 files.
# 491 files processed out of 2700 files.
# 492 files processed out of 2700 files.
# 493 files processed out of 2700 files.
# 494 files processed out of 2700 files.
# 495 files processed out of 2700 files.
# 496 files processed out of 2700 files.
# 497 files processed out of 2700 files.
# 498 files processed out of 2700 files.
# 499 files processed out of 2700 files.
# 500 files processed out of 2700 files.
# 501 files processed out of 2700 files.
# 502 files processed out of 2700 files.
# 503 files processed out of 2700 files.
# 504 files processed out of 2700 files.
# 505 files processed out of 2700 files.
# 506 files processed out of 2700 files.
# 507 files processed out of 2700 files.
# 508 files processed out of 2700 files.
# 509 files processed out of 2700 files.
# 510 files processed out of 2700 files.
# 511 files processed out of 2700 files.
# 512 files processed out of 2700 files.
# 513 files processed out of 2700 files.
# 514 files processed out of 2700 files.
# 515 files processed out of 2700 files.
# 516 files processed out of 2700 files.
# 517 files processed out of 2700 files.
# 518 files processed out of 2700 files.
# 519 files processed out of 2700 files.
# 520 files processed out of 2700 files.
# 521 files processed out of 2700 files.
# 522 files processed out of 2700 files.
# 523 files processed out of 2700 files.
# 524 files processed out of 2700 files.
# 525 files processed out of 2700 files.
# 526 files processed out of 2700 files.
# 527 files processed out of 2700 files.
# 528 files processed out of 2700 files.
# 529 files processed out of 2700 files.
# 530 files processed out of 2700 files.
# 531 files processed out of 2700 files.
# 532 files processed out of 2700 files.
# 533 files processed out of 2700 files.
# 534 files processed out of 2700 files.
# 535 files processed out of 2700 files.
# 536 files processed out of 2700 files.
# 537 files processed out of 2700 files.
# 538 files processed out of 2700 files.
# 539 files processed out of 2700 files.
# 540 files processed out of 2700 files.
# 541 files processed out of 2700 files.
# 542 files processed out of 2700 files.
# 543 files processed out of 2700 files.
# 544 files processed out of 2700 files.
# 545 files processed out of 2700 files.
# 546 files processed out of 2700 files.
# 547 files processed out of 2700 files.
# 548 files processed out of 2700 files.
# 549 files processed out of 2700 files.
# 550 files processed out of 2700 files.
# 551 files processed out of 2700 files.
# 552 files processed out of 2700 files.
# 553 files processed out of 2700 files.
# 554 files processed out of 2700 files.
# 555 files processed out of 2700 files.
# 556 files processed out of 2700 files.
# 557 files processed out of 2700 files.
# 558 files processed out of 2700 files.
# 559 files processed out of 2700 files.
# 560 files processed out of 2700 files.
# 561 files processed out of 2700 files.
# 562 files processed out of 2700 files.
# 563 files processed out of 2700 files.
# 564 files processed out of 2700 files.
# 565 files processed out of 2700 files.
# 566 files processed out of 2700 files.
# 567 files processed out of 2700 files.
# 568 files processed out of 2700 files.
# 569 files processed out of 2700 files.
# 570 files processed out of 2700 files.
# 571 files processed out of 2700 files.
# 572 files processed out of 2700 files.
# 573 files processed out of 2700 files.
# 574 files processed out of 2700 files.
# 575 files processed out of 2700 files.
# 576 files processed out of 2700 files.
# 577 files processed out of 2700 files.
# 578 files processed out of 2700 files.
# 579 files processed out of 2700 files.
# 580 files processed out of 2700 files.
# 581 files processed out of 2700 files.
# 582 files processed out of 2700 files.
# 583 files processed out of 2700 files.
# 584 files processed out of 2700 files.
# 585 files processed out of 2700 files.
# 586 files processed out of 2700 files.
# 587 files processed out of 2700 files.
# 588 files processed out of 2700 files.
# 589 files processed out of 2700 files.
# 590 files processed out of 2700 files.
# 591 files processed out of 2700 files.
# 592 files processed out of 2700 files.
# 593 files processed out of 2700 files.
# 594 files processed out of 2700 files.
# 595 files processed out of 2700 files.
# 596 files processed out of 2700 files.
# 597 files processed out of 2700 files.
# 598 files processed out of 2700 files.
# 599 files processed out of 2700 files.
# 600 files processed out of 2700 files.
# 601 files processed out of 2700 files.
# 602 files processed out of 2700 files.
# 603 files processed out of 2700 files.
# 604 files processed out of 2700 files.
# 605 files processed out of 2700 files.
# 606 files processed out of 2700 files.
# 607 files processed out of 2700 files.
# 608 files processed out of 2700 files.
# 609 files processed out of 2700 files.
# 610 files processed out of 2700 files.
# 611 files processed out of 2700 files.
# 612 files processed out of 2700 files.
# 613 files processed out of 2700 files.
# 614 files processed out of 2700 files.
# 615 files processed out of 2700 files.
# 616 files processed out of 2700 files.
# 617 files processed out of 2700 files.
# 618 files processed out of 2700 files.
# 619 files processed out of 2700 files.
# 620 files processed out of 2700 files.
# 621 files processed out of 2700 files.
# 622 files processed out of 2700 files.
# 623 files processed out of 2700 files.
# 624 files processed out of 2700 files.
# 625 files processed out of 2700 files.
# 626 files processed out of 2700 files.
# 627 files processed out of 2700 files.
# 628 files processed out of 2700 files.
# 629 files processed out of 2700 files.
# 630 files processed out of 2700 files.
# 631 files processed out of 2700 files.
# 632 files processed out of 2700 files.
# 633 files processed out of 2700 files.
# 634 files processed out of 2700 files.
# 635 files processed out of 2700 files.
# 636 files processed out of 2700 files.
# 637 files processed out of 2700 files.
# 638 files processed out of 2700 files.
# 639 files processed out of 2700 files.
# 640 files processed out of 2700 files.
# 641 files processed out of 2700 files.
# 642 files processed out of 2700 files.
# 643 files processed out of 2700 files.
# 644 files processed out of 2700 files.
# 645 files processed out of 2700 files.
# 646 files processed out of 2700 files.
# 647 files processed out of 2700 files.
# 648 files processed out of 2700 files.
# 649 files processed out of 2700 files.
# 650 files processed out of 2700 files.
# 651 files processed out of 2700 files.
# 652 files processed out of 2700 files.
# 653 files processed out of 2700 files.
# 654 files processed out of 2700 files.
# 655 files processed out of 2700 files.
# 656 files processed out of 2700 files.
# 657 files processed out of 2700 files.
# 658 files processed out of 2700 files.
# 659 files processed out of 2700 files.
# 660 files processed out of 2700 files.
# 661 files processed out of 2700 files.
# 662 files processed out of 2700 files.
# 663 files processed out of 2700 files.
# 664 files processed out of 2700 files.
# 665 files processed out of 2700 files.
# 666 files processed out of 2700 files.
# 667 files processed out of 2700 files.
# 668 files processed out of 2700 files.
# 669 files processed out of 2700 files.
# 670 files processed out of 2700 files.
# 671 files processed out of 2700 files.
# 672 files processed out of 2700 files.
# 673 files processed out of 2700 files.
# 674 files processed out of 2700 files.
# 675 files processed out of 2700 files.
# 676 files processed out of 2700 files.
# 677 files processed out of 2700 files.
# 678 files processed out of 2700 files.
# 679 files processed out of 2700 files.
# 680 files processed out of 2700 files.
# 681 files processed out of 2700 files.
# 682 files processed out of 2700 files.
# 683 files processed out of 2700 files.
# 684 files processed out of 2700 files.
# 685 files processed out of 2700 files.
# 686 files processed out of 2700 files.
# 687 files processed out of 2700 files.
# 688 files processed out of 2700 files.
# 689 files processed out of 2700 files.
# 690 files processed out of 2700 files.
# 691 files processed out of 2700 files.
# 692 files processed out of 2700 files.
# 693 files processed out of 2700 files.
# 694 files processed out of 2700 files.
# 695 files processed out of 2700 files.
# 696 files processed out of 2700 files.
# 697 files processed out of 2700 files.
# 698 files processed out of 2700 files.
# 699 files processed out of 2700 files.
# 700 files processed out of 2700 files.
# 701 files processed out of 2700 files.
# 702 files processed out of 2700 files.
# 703 files processed out of 2700 files.
# 704 files processed out of 2700 files.
# 705 files processed out of 2700 files.
# 706 files processed out of 2700 files.
# 707 files processed out of 2700 files.
# 708 files processed out of 2700 files.
# 709 files processed out of 2700 files.
# 710 files processed out of 2700 files.
# 711 files processed out of 2700 files.
# 712 files processed out of 2700 files.
# 713 files processed out of 2700 files.
# 714 files processed out of 2700 files.
# 715 files processed out of 2700 files.
# 716 files processed out of 2700 files.
# 717 files processed out of 2700 files.
# 718 files processed out of 2700 files.
# 719 files processed out of 2700 files.
# 720 files processed out of 2700 files.
# 721 files processed out of 2700 files.
# 722 files processed out of 2700 files.
# 723 files processed out of 2700 files.
# 724 files processed out of 2700 files.
# 725 files processed out of 2700 files.
# 726 files processed out of 2700 files.
# 727 files processed out of 2700 files.
# 728 files processed out of 2700 files.
# 729 files processed out of 2700 files.
# 730 files processed out of 2700 files.
# 731 files processed out of 2700 files.
# 732 files processed out of 2700 files.
# 733 files processed out of 2700 files.
# 734 files processed out of 2700 files.
# 735 files processed out of 2700 files.
# 736 files processed out of 2700 files.
# 737 files processed out of 2700 files.
# 738 files processed out of 2700 files.
# 739 files processed out of 2700 files.
# 740 files processed out of 2700 files.
# 741 files processed out of 2700 files.
# 742 files processed out of 2700 files.
# 743 files processed out of 2700 files.
# 744 files processed out of 2700 files.
# 745 files processed out of 2700 files.
# 746 files processed out of 2700 files.
# 747 files processed out of 2700 files.
# 748 files processed out of 2700 files.
# 749 files processed out of 2700 files.
# 750 files processed out of 2700 files.
# 751 files processed out of 2700 files.
# 752 files processed out of 2700 files.
# 753 files processed out of 2700 files.
# 754 files processed out of 2700 files.
# 755 files processed out of 2700 files.
# 756 files processed out of 2700 files.
# 757 files processed out of 2700 files.
# 758 files processed out of 2700 files.
# 759 files processed out of 2700 files.
# 760 files processed out of 2700 files.
# 761 files processed out of 2700 files.
# 762 files processed out of 2700 files.
# 763 files processed out of 2700 files.
# 764 files processed out of 2700 files.
# 765 files processed out of 2700 files.
# 766 files processed out of 2700 files.
# 767 files processed out of 2700 files.
# 768 files processed out of 2700 files.
# 769 files processed out of 2700 files.
# 770 files processed out of 2700 files.
# 771 files processed out of 2700 files.
# 772 files processed out of 2700 files.
# 773 files processed out of 2700 files.
# 774 files processed out of 2700 files.
# 775 files processed out of 2700 files.
# 776 files processed out of 2700 files.
# 777 files processed out of 2700 files.
# 778 files processed out of 2700 files.
# 779 files processed out of 2700 files.
# 780 files processed out of 2700 files.
# 781 files processed out of 2700 files.
# 782 files processed out of 2700 files.
# 783 files processed out of 2700 files.
# 784 files processed out of 2700 files.
# 785 files processed out of 2700 files.
# 786 files processed out of 2700 files.
# 787 files processed out of 2700 files.
# 788 files processed out of 2700 files.
# 789 files processed out of 2700 files.
# 790 files processed out of 2700 files.
# 791 files processed out of 2700 files.
# 792 files processed out of 2700 files.
# 793 files processed out of 2700 files.
# 794 files processed out of 2700 files.
# 795 files processed out of 2700 files.
# 796 files processed out of 2700 files.
# 797 files processed out of 2700 files.
# 798 files processed out of 2700 files.
# 799 files processed out of 2700 files.
# 800 files processed out of 2700 files.
# 801 files processed out of 2700 files.
# 802 files processed out of 2700 files.
# 803 files processed out of 2700 files.
# 804 files processed out of 2700 files.
# 805 files processed out of 2700 files.
# 806 files processed out of 2700 files.
# 807 files processed out of 2700 files.
# 808 files processed out of 2700 files.
# 809 files processed out of 2700 files.
# 810 files processed out of 2700 files.
# 811 files processed out of 2700 files.
# 812 files processed out of 2700 files.
# 813 files processed out of 2700 files.
# 814 files processed out of 2700 files.
# 815 files processed out of 2700 files.
# 816 files processed out of 2700 files.
# 817 files processed out of 2700 files.
# 818 files processed out of 2700 files.
# 819 files processed out of 2700 files.
# 820 files processed out of 2700 files.
# 821 files processed out of 2700 files.
# 822 files processed out of 2700 files.
# 823 files processed out of 2700 files.
# 824 files processed out of 2700 files.
# 825 files processed out of 2700 files.
# 826 files processed out of 2700 files.
# 827 files processed out of 2700 files.
# 828 files processed out of 2700 files.
# 829 files processed out of 2700 files.
# 830 files processed out of 2700 files.
# 831 files processed out of 2700 files.
# ...
# 2301 files processed out of 2700 files.
# 2302 files processed out of 2700 files.
# 2303 files processed out of 2700 files.
# 2304 files processed out of 2700 files.
# 2305 files processed out of 2700 files.
# 2306 files processed out of 2700 files.
# 2307 files processed out of 2700 files.
# 2308 files processed out of 2700 files.
# 2309 files processed out of 2700 files.
# 2310 files processed out of 2700 files.
# 2311 files processed out of 2700 files.
# 2312 files processed out of 2700 files.
# 2313 files processed out of 2700 files.
# 2314 files processed out of 2700 files.
# 2315 files processed out of 2700 files.
# 2316 files processed out of 2700 files.
# 2317 files processed out of 2700 files.
# 2318 files processed out of 2700 files.
# 2319 files processed out of 2700 files.
# 2320 files processed out of 2700 files.
# 2321 files processed out of 2700 files.
# 2322 files processed out of 2700 files.
# 2323 files processed out of 2700 files.
# 2324 files processed out of 2700 files.
# 2325 files processed out of 2700 files.
# 2326 files processed out of 2700 files.
# 2327 files processed out of 2700 files.
# 2328 files processed out of 2700 files.
# 2329 files processed out of 2700 files.
# 2330 files processed out of 2700 files.
# 2331 files processed out of 2700 files.
# 2332 files processed out of 2700 files.
# 2333 files processed out of 2700 files.
# 2334 files processed out of 2700 files.
# 2335 files processed out of 2700 files.
# 2336 files processed out of 2700 files.
# 2337 files processed out of 2700 files.
# 2338 files processed out of 2700 files.
# 2339 files processed out of 2700 files.
# 2340 files processed out of 2700 files.
# 2341 files processed out of 2700 files.
# 2342 files processed out of 2700 files.
# 2343 files processed out of 2700 files.
# 2344 files processed out of 2700 files.
# 2345 files processed out of 2700 files.
# 2346 files processed out of 2700 files.
# 2347 files processed out of 2700 files.
# 2348 files processed out of 2700 files.
# 2349 files processed out of 2700 files.
# 2350 files processed out of 2700 files.
# 2351 files processed out of 2700 files.
# 2352 files processed out of 2700 files.
# 2353 files processed out of 2700 files.
# 2354 files processed out of 2700 files.
# 2355 files processed out of 2700 files.
# 2356 files processed out of 2700 files.
# 2357 files processed out of 2700 files.
# 2358 files processed out of 2700 files.
# 2359 files processed out of 2700 files.
# 2360 files processed out of 2700 files.
# 2361 files processed out of 2700 files.
# 2362 files processed out of 2700 files.
# 2363 files processed out of 2700 files.
# 2364 files processed out of 2700 files.
# 2365 files processed out of 2700 files.
# 2366 files processed out of 2700 files.
# 2367 files processed out of 2700 files.
# 2368 files processed out of 2700 files.
# 2369 files processed out of 2700 files.
# 2370 files processed out of 2700 files.
# 2371 files processed out of 2700 files.
# 2372 files processed out of 2700 files.
# 2373 files processed out of 2700 files.
# 2374 files processed out of 2700 files.
# 2375 files processed out of 2700 files.
# 2376 files processed out of 2700 files.
# 2377 files processed out of 2700 files.
# 2378 files processed out of 2700 files.
# 2379 files processed out of 2700 files.
# 2380 files processed out of 2700 files.
# 2381 files processed out of 2700 files.
# 2382 files processed out of 2700 files.
# 2383 files processed out of 2700 files.
# 2384 files processed out of 2700 files.
# 2385 files processed out of 2700 files.
# 2386 files processed out of 2700 files.
# 2387 files processed out of 2700 files.
# 2388 files processed out of 2700 files.
# 2389 files processed out of 2700 files.
# 2390 files processed out of 2700 files.
# 2391 files processed out of 2700 files.
# 2392 files processed out of 2700 files.
# 2393 files processed out of 2700 files.
# 2394 files processed out of 2700 files.
# 2395 files processed out of 2700 files.
# 2396 files processed out of 2700 files.
# 2397 files processed out of 2700 files.
# 2398 files processed out of 2700 files.
# 2399 files processed out of 2700 files.
# 2400 files processed out of 2700 files.
# 2401 files processed out of 2700 files.
# 2402 files processed out of 2700 files.
# 2403 files processed out of 2700 files.
# 2404 files processed out of 2700 files.
# 2405 files processed out of 2700 files.
# 2406 files processed out of 2700 files.
# 2407 files processed out of 2700 files.
# 2408 files processed out of 2700 files.
# 2409 files processed out of 2700 files.
# 2410 files processed out of 2700 files.
# 2411 files processed out of 2700 files.
# 2412 files processed out of 2700 files.
# 2413 files processed out of 2700 files.
# 2414 files processed out of 2700 files.
# 2415 files processed out of 2700 files.
# 2416 files processed out of 2700 files.
# 2417 files processed out of 2700 files.
# 2418 files processed out of 2700 files.
# 2419 files processed out of 2700 files.
# 2420 files processed out of 2700 files.
# 2421 files processed out of 2700 files.
# 2422 files processed out of 2700 files.
# 2423 files processed out of 2700 files.
# 2424 files processed out of 2700 files.
# 2425 files processed out of 2700 files.
# 2426 files processed out of 2700 files.
# 2427 files processed out of 2700 files.
# 2428 files processed out of 2700 files.
# 2429 files processed out of 2700 files.
# 2430 files processed out of 2700 files.
# 2431 files processed out of 2700 files.
# 2432 files processed out of 2700 files.
# 2433 files processed out of 2700 files.
# 2434 files processed out of 2700 files.
# 2435 files processed out of 2700 files.
# 2436 files processed out of 2700 files.
# 2437 files processed out of 2700 files.
# 2438 files processed out of 2700 files.
# 2439 files processed out of 2700 files.
# 2440 files processed out of 2700 files.
# 2441 files processed out of 2700 files.
# 2442 files processed out of 2700 files.
# 2443 files processed out of 2700 files.
# 2444 files processed out of 2700 files.
# 2445 files processed out of 2700 files.
# 2446 files processed out of 2700 files.
# 2447 files processed out of 2700 files.
# 2448 files processed out of 2700 files.
# 2449 files processed out of 2700 files.
# 2450 files processed out of 2700 files.
# 2451 files processed out of 2700 files.
# 2452 files processed out of 2700 files.
# 2453 files processed out of 2700 files.
# 2454 files processed out of 2700 files.
# 2455 files processed out of 2700 files.
# 2456 files processed out of 2700 files.
# 2457 files processed out of 2700 files.
# 2458 files processed out of 2700 files.
# 2459 files processed out of 2700 files.
# 2460 files processed out of 2700 files.
# 2461 files processed out of 2700 files.
# 2462 files processed out of 2700 files.
# 2463 files processed out of 2700 files.
# 2464 files processed out of 2700 files.
# 2465 files processed out of 2700 files.
# 2466 files processed out of 2700 files.
# 2467 files processed out of 2700 files.
# 2468 files processed out of 2700 files.
# 2469 files processed out of 2700 files.
# 2470 files processed out of 2700 files.
# 2471 files processed out of 2700 files.
# 2472 files processed out of 2700 files.
# 2473 files processed out of 2700 files.
# 2474 files processed out of 2700 files.
# 2475 files processed out of 2700 files.
# 2476 files processed out of 2700 files.
# 2477 files processed out of 2700 files.
# 2478 files processed out of 2700 files.
# 2479 files processed out of 2700 files.
# 2480 files processed out of 2700 files.
# 2481 files processed out of 2700 files.
# 2482 files processed out of 2700 files.
# 2483 files processed out of 2700 files.
# 2484 files processed out of 2700 files.
# 2485 files processed out of 2700 files.
# 2486 files processed out of 2700 files.
# 2487 files processed out of 2700 files.
# 2488 files processed out of 2700 files.
# 2489 files processed out of 2700 files.
# 2490 files processed out of 2700 files.
# 2491 files processed out of 2700 files.
# 2492 files processed out of 2700 files.
# 2493 files processed out of 2700 files.
# 2494 files processed out of 2700 files.
# 2495 files processed out of 2700 files.
# 2496 files processed out of 2700 files.
# 2497 files processed out of 2700 files.
# 2498 files processed out of 2700 files.
# 2499 files processed out of 2700 files.
# 2500 files processed out of 2700 files.
# 2501 files processed out of 2700 files.
# 2502 files processed out of 2700 files.
# 2503 files processed out of 2700 files.
# 2504 files processed out of 2700 files.
# 2505 files processed out of 2700 files.
# 2506 files processed out of 2700 files.
# 2507 files processed out of 2700 files.
# 2508 files processed out of 2700 files.
# 2509 files processed out of 2700 files.
# 2510 files processed out of 2700 files.
# 2511 files processed out of 2700 files.
# 2512 files processed out of 2700 files.
# 2513 files processed out of 2700 files.
# 2514 files processed out of 2700 files.
# 2515 files processed out of 2700 files.
# 2516 files processed out of 2700 files.
# 2517 files processed out of 2700 files.
# 2518 files processed out of 2700 files.
# 2519 files processed out of 2700 files.
# 2520 files processed out of 2700 files.
# 2521 files processed out of 2700 files.
# 2522 files processed out of 2700 files.
# 2523 files processed out of 2700 files.
# 2524 files processed out of 2700 files.
# 2525 files processed out of 2700 files.
# 2526 files processed out of 2700 files.
# 2527 files processed out of 2700 files.
# 2528 files processed out of 2700 files.
# 2529 files processed out of 2700 files.
# 2530 files processed out of 2700 files.
# 2531 files processed out of 2700 files.
# 2532 files processed out of 2700 files.
# 2533 files processed out of 2700 files.
# 2534 files processed out of 2700 files.
# 2535 files processed out of 2700 files.
# 2536 files processed out of 2700 files.
# 2537 files processed out of 2700 files.
# 2538 files processed out of 2700 files.
# 2539 files processed out of 2700 files.
# 2540 files processed out of 2700 files.
# 2541 files processed out of 2700 files.
# 2542 files processed out of 2700 files.
# 2543 files processed out of 2700 files.
# 2544 files processed out of 2700 files.
# 2545 files processed out of 2700 files.
# 2546 files processed out of 2700 files.
# 2547 files processed out of 2700 files.
# 2548 files processed out of 2700 files.
# 2549 files processed out of 2700 files.
# 2550 files processed out of 2700 files.
# 2551 files processed out of 2700 files.
# 2552 files processed out of 2700 files.
# 2553 files processed out of 2700 files.
# 2554 files processed out of 2700 files.
# 2555 files processed out of 2700 files.
# 2556 files processed out of 2700 files.
# 2557 files processed out of 2700 files.
# 2558 files processed out of 2700 files.
# 2559 files processed out of 2700 files.
# 2560 files processed out of 2700 files.
# 2561 files processed out of 2700 files.
# 2562 files processed out of 2700 files.
# 2563 files processed out of 2700 files.
# 2564 files processed out of 2700 files.
# 2565 files processed out of 2700 files.
# 2566 files processed out of 2700 files.
# 2567 files processed out of 2700 files.
# 2568 files processed out of 2700 files.
# 2569 files processed out of 2700 files.
# 2570 files processed out of 2700 files.
# 2571 files processed out of 2700 files.
# 2572 files processed out of 2700 files.
# 2573 files processed out of 2700 files.
# 2574 files processed out of 2700 files.
# 2575 files processed out of 2700 files.
# 2576 files processed out of 2700 files.
# 2577 files processed out of 2700 files.
# 2578 files processed out of 2700 files.
# 2579 files processed out of 2700 files.
# 2580 files processed out of 2700 files.
# 2581 files processed out of 2700 files.
# 2582 files processed out of 2700 files.
# 2583 files processed out of 2700 files.
# 2584 files processed out of 2700 files.
# 2585 files processed out of 2700 files.
# 2586 files processed out of 2700 files.
# 2587 files processed out of 2700 files.
# 2588 files processed out of 2700 files.
# 2589 files processed out of 2700 files.
# 2590 files processed out of 2700 files.
# 2591 files processed out of 2700 files.
# 2592 files processed out of 2700 files.
# 2593 files processed out of 2700 files.
# 2594 files processed out of 2700 files.
# 2595 files processed out of 2700 files.
# 2596 files processed out of 2700 files.
# 2597 files processed out of 2700 files.
# 2598 files processed out of 2700 files.
# 2599 files processed out of 2700 files.
# 2600 files processed out of 2700 files.
# 2601 files processed out of 2700 files.
# 2602 files processed out of 2700 files.
# 2603 files processed out of 2700 files.
# 2604 files processed out of 2700 files.
# 2605 files processed out of 2700 files.
# 2606 files processed out of 2700 files.
# 2607 files processed out of 2700 files.
# 2608 files processed out of 2700 files.
# 2609 files processed out of 2700 files.
# 2610 files processed out of 2700 files.
# 2611 files processed out of 2700 files.
# 2612 files processed out of 2700 files.
# 2613 files processed out of 2700 files.
# 2614 files processed out of 2700 files.
# 2615 files processed out of 2700 files.
# 2616 files processed out of 2700 files.
# 2617 files processed out of 2700 files.
# 2618 files processed out of 2700 files.
# 2619 files processed out of 2700 files.
# 2620 files processed out of 2700 files.
# 2621 files processed out of 2700 files.
# 2622 files processed out of 2700 files.
# 2623 files processed out of 2700 files.
# 2624 files processed out of 2700 files.
# 2625 files processed out of 2700 files.
# 2626 files processed out of 2700 files.
# 2627 files processed out of 2700 files.
# 2628 files processed out of 2700 files.
# 2629 files processed out of 2700 files.
# 2630 files processed out of 2700 files.
# 2631 files processed out of 2700 files.
# 2632 files processed out of 2700 files.
# 2633 files processed out of 2700 files.
# 2634 files processed out of 2700 files.
# 2635 files processed out of 2700 files.
# 2636 files processed out of 2700 files.
# 2637 files processed out of 2700 files.
# 2638 files processed out of 2700 files.
# 2639 files processed out of 2700 files.
# 2640 files processed out of 2700 files.
# 2641 files processed out of 2700 files.
# 2642 files processed out of 2700 files.
# 2643 files processed out of 2700 files.
# 2644 files processed out of 2700 files.
# 2645 files processed out of 2700 files.
# 2646 files processed out of 2700 files.
# 2647 files processed out of 2700 files.
# 2648 files processed out of 2700 files.
# 2649 files processed out of 2700 files.
# 2650 files processed out of 2700 files.
# 2651 files processed out of 2700 files.
# 2652 files processed out of 2700 files.
# 2653 files processed out of 2700 files.
# 2654 files processed out of 2700 files.
# 2655 files processed out of 2700 files.
# 2656 files processed out of 2700 files.
# 2657 files processed out of 2700 files.
# 2658 files processed out of 2700 files.
# 2659 files processed out of 2700 files.
# 2660 files processed out of 2700 files.
# 2661 files processed out of 2700 files.
# 2662 files processed out of 2700 files.
# 2663 files processed out of 2700 files.
# 2664 files processed out of 2700 files.
# 2665 files processed out of 2700 files.
# 2666 files processed out of 2700 files.
# 2667 files processed out of 2700 files.
# 2668 files processed out of 2700 files.
# 2669 files processed out of 2700 files.
# 2670 files processed out of 2700 files.
# 2671 files processed out of 2700 files.
# 2672 files processed out of 2700 files.
# 2673 files processed out of 2700 files.
# 2674 files processed out of 2700 files.
# 2675 files processed out of 2700 files.
# 2676 files processed out of 2700 files.
# 2677 files processed out of 2700 files.
# 2678 files processed out of 2700 files.
# 2679 files processed out of 2700 files.
# 2680 files processed out of 2700 files.
# 2681 files processed out of 2700 files.
# 2682 files processed out of 2700 files.
# 2683 files processed out of 2700 files.
# 2684 files processed out of 2700 files.
# 2685 files processed out of 2700 files.
# 2686 files processed out of 2700 files.
# 2687 files processed out of 2700 files.
# 2688 files processed out of 2700 files.
# 2689 files processed out of 2700 files.
# 2690 files processed out of 2700 files.
# 2691 files processed out of 2700 files.
# 2692 files processed out of 2700 files.
# 2693 files processed out of 2700 files.
# 2694 files processed out of 2700 files.
# 2695 files processed out of 2700 files.
# 2696 files processed out of 2700 files.
# 2697 files processed out of 2700 files.
# 2698 files processed out of 2700 files.
# 2699 files processed out of 2700 files.
# 2700 files processed out of 2700 files.

# %%
path="data/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset"
subpaths = ["SVM/test_unique","SVM/train_unique"]

f,f_label = collect_files(path, subpaths, True)
df_sizes, bad_images = summarize_images(f, meta_df)
df_sizes.describe()
df_size_plots(df_sizes)
# Out:
# --- Parsing 3115 images ---
# -> 0 images parsed
# -> 500 images parsed
# -> 1000 images parsed
# -> 1500 images parsed
# -> 2000 images parsed
# -> 2500 images parsed
# -> 3000 images parsed
# --- There were 0 images not included in the metadata .csv ---

# %%
def hog_descriptor(f_paths,image = False): 
    
    '''Computes Histogram of Oriented Gradients 
    
    Args:
        f_path (type = list): list of image filepaths
        image (type = bool/list): True to capture hod image array for ALL images, list to capature only the indexes in the list
    Returns:
        tuple (hog_fd, img_dict) where:
        hog_fd (type = list): hog feature description 
        img_dict (type = list): hog image  
    '''
    
    hog_fd = []
    img_dict = {}
    i = 0
    print_every = 500
        
    for filename in f_paths:
        file_ext = filename.split(".")[-1]
        if ( file_ext in ["jpeg","jpg","png"]):
            if (i % print_every == 0):
                print("-> {} images parsed".format(i))
    
            img = imread(filename)
            try:
                if ((image == True) or (i in image)):
                    fd, hog_image = hog(img, orientations=8, pixels_per_cell=(16, 16), cells_per_block=(2, 2),  transform_sqrt=True, block_norm="L1", visualize=True)
                    hog_fd.append(fd)
                    img_dict[i]= hog_image                
                else:
                    fd = hog(img, orientations=8, pixels_per_cell=(16, 16), cells_per_block=(2, 2),  transform_sqrt= True, block_norm="L1")
                    hog_fd.append(fd)

                
                i += 1
            except ValueError:
                print(ValueError)
                print("{} - shape = {}".format(filename, img.shape))
            except:
                print("Unknown exception occurred.") 
            
        else:
            print("Skipping {}.".format(filename))
            
    return(hog_fd, img_dict)

# %%
subpaths = ["SVM/train_unique"]

f_train,label_train = collect_files(path, subpaths, True)

#create hog decriptions for modified training set
hog_train, img_train = hog_descriptor(f_train,[1,2,3])
# Out:
# -> 0 images parsed
# -> 500 images parsed
# -> 1000 images parsed
# -> 1500 images parsed
# -> 2000 images parsed
# -> 2500 images parsed

# %%
len(hog_train), len(f_train)
# Out:
# (2700, 2700)

# %%
ex_img_train = imread(f_train[2])
fig, ax= plt.subplots(1,2,figsize=(10,5))
ax[0].imshow(img_train[2]/img_train[2].max()) 
ax[1].imshow(ex_img_train)

# %%
subpaths = ["SVM/test_unique"]

f_test, label_test = collect_files(path, subpaths, True)

#create hog decriptions for modified test set
hog_test, img_test = hog_descriptor(f_test, [2,3])
# Out:
# -> 0 images parsed

# %%
print(len(hog_test)+len(hog_train))
print(len(hog_test)+len(hog_train) == len(f))
# Out:
# 3115
# True

# %%
ex_img_test = imread(f_test[2])
fig, ax= plt.subplots(1,2,figsize=(10,5))
ax[0].imshow(img_test[2]/img_test[2].max()) 
ax[1].imshow(ex_img_test)
# imshow(img_test[2]/img_test[2].max())

# %%
def data_stack(hog_fd,label):
    ''' Creates stacked array of hog descriptors and a flattened array of their corresponding labels

    Args:
        hog_fd (type = list): list of hog feature description 
        label (list): list of labels of hog_fd
    Returns:
        tuple (X, y) where:
        X (type = array): stacked hog feature description in hog_fd  
        y (type = array): flattened array of labels of hog_fd 
    '''
    label =  np.array(label).reshape(len(label),1)
    hog_fd = np.array(hog_fd)
    
#     data_array = np.hstack((hog_fd,label))
    
#     x = data_array[:,:-1]
#     y = data_array[:,-1:].ravel()
    x,y = hog_fd,label.ravel()
    return (x,y)

# %%
x_train,y_train = data_stack(hog_train,label_train)
x_test,y_test = data_stack(hog_test,label_test)

# %%
# param_grid = {'C': [0.1,1, 10], 'gamma': [1,0.1,0.01],'kernel': ['linear','rbf', 'poly']}
# model = GridSearchCV(SVC(),param_grid,refit=True,verbose=2, n_jobs = -1)

# %%
model = make_pipeline(StandardScaler(), SVC(C=1, gamma=0.1, kernel='poly',probability = True,random_state = 7))
model.fit(x_train,y_train)

# %%
predictions_probs = model.predict_proba(x_test)
predictions = model.predict(x_test)

# %%
fpr, tpr,_ = metrics.roc_curve(y_test,predictions_probs[:,1] ,pos_label='Pnemonia')
auc = metrics.roc_auc_score(y_test,predictions_probs[:,1])
plt.figure(figsize=(6,6))
plt.plot(fpr,tpr,label='(auc={:3.2f})'.format(auc))
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title("ROC Curve")
plt.legend()

# %%
prec, rec, threshs = metrics.precision_recall_curve(y_test,predictions_probs[:,1],pos_label='Pnemonia')
auc = metrics.auc(rec, prec)
plt.figure(figsize=(6,6))
plt.plot(rec,prec,label='(auc={:3.2f})'.format(auc))
plt.xlabel('recall')
plt.ylabel('precision')
plt.title("PR curve")
plt.legend()

# %%
data = {"y_test": y_test, "y_hat":predictions}
df = pd.DataFrame(data, columns=["y_test", "y_hat"])
confusion_matrix = pd.crosstab(df['y_test'],df['y_hat'],rownames=["Actual"],colnames=['Predicted'])
f, ax = plt.subplots(figsize=(7,5))
sn.heatmap(confusion_matrix, annot=True)
plt.show()
